# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Return a random sample of items from a DataFrame
df.sample()
# Out:
#        job_title_short               job_title job_location    job_via  \
# 438579    Data Analyst  Data Analyst – PowerBI  England, UK  via BeBee
#
#        job_schedule_type  job_work_from_home search_location  \
# 438579         Full-time               False  United Kingdom
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 438579 2023-09-21 16:06:06                   True                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 438579  United Kingdom        None              NaN              NaN
#
#                        company_name        job_skills  \
# 438579  Open Data Science Conferenc  ['sql', 'excel']
#
#                                           job_type_skills
# 438579  {'analyst_tools': ['excel'], 'programming': ['...

# %%
# n= is number of items to return
df.sample(n=5)
# Out:
#        job_title_short                                          job_title  \
# 706035    Data Analyst                         Data Analyst (Credit Risk)
# 666451  Data Scientist  Data scientist needed to give insights on raw ...
# 427598  Data Scientist                                     Data Scientist
# 753996    Data Analyst        Data Analyst - Contrôleur de Gestion RH H/F
# 303976    Data Analyst                         Data and Reporting Analyst
#
#                              job_location            job_via  \
# 706035  Taguig, Metro Manila, Philippines       via LinkedIn
# 666451                           Anywhere         via Upwork
# 427598                Geneva, Switzerland  via BeBee Schweiz
# 753996                      Paris, France      via HelloWork
# 303976                           Anywhere       via LinkedIn
#
#                job_schedule_type  job_work_from_home search_location  \
# 706035                      None               False     Philippines
# 666451  Contractor and Temp work                True           Sudan
# 427598                 Full-time               False     Switzerland
# 753996                 Full-time               False          France
# 303976                 Full-time                True          Greece
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 706035 2023-01-31 03:17:25                  False                 False
# 666451 2023-09-19 03:01:56                  False                 False
# 427598 2023-06-14 16:25:59                  False                 False
# 753996 2023-07-05 20:29:16                  False                 False
# 303976 2023-05-25 17:46:32                  False                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 706035  Philippines        None              NaN              NaN
# 666451        Sudan        hour              NaN            100.0
# 427598  Switzerland        None              NaN              NaN
# 753996       France        None              NaN              NaN
# 303976       Greece        None              NaN              NaN
#
#        company_name                                         job_skills  \
# 706035          ING                        ['sql', 'go', 'sas', 'sas']
# 666451       Upwork                                               None
# 427598        Total  ['python', 'mongodb', 'mongodb', 'postgresql',...
# 753996        AP-HP                                               None
# 303976    Recognyte                               ['tableau', 'excel']
#
#                                           job_type_skills
# 706035  {'analyst_tools': ['sas'], 'programming': ['sq...
# 666451                                               None
# 427598  {'cloud': ['aws'], 'databases': ['mongodb', 'p...
# 753996                                               None
# 303976            {'analyst_tools': ['tableau', 'excel']}

# %%
# Fraction of rows to return (e.g., frac=0.1 returns 10% of the data)
df.sample(frac=0.1)
# Out:
#               job_title_short  \
# 190161         Data Scientist
# 304301          Data Engineer
# 234359         Data Scientist
# 521001         Data Scientist
# 296061          Data Engineer
# ...                       ...
# 780714         Data Scientist
# 740398         Data Scientist
# 663221           Data Analyst
# 649855  Senior Data Scientist
# 637982         Data Scientist
#
#                                                 job_title  \
# 190161                                     Data scientist
# 304301                                Azure Data Engineer
# 234359                                     Data Scientist
# 521001                                Data Science Intern
# 296061                                 Lead Data Engineer
# ...                                                   ...
# 780714                              Junior data scientist
# 740398  Internship / Thesis Data Science & Modelling I...
# 663221                                Data Analyst Intern
# 649855                              Senior Data Scientist
# 637982                                     Data Scientist
#
#                        job_location                         job_via  \
# 190161                Lille, France                       via BeBee
# 304301                Arlington, VA                 via Trabajo.org
# 234359                St. Louis, MO  via Abile Headquarters - ICIMS
# 521001                    Niles, IL                    via LinkedIn
# 296061               Pontypridd, UK                    via LinkedIn
# ...                             ...                             ...
# 780714               Bridgeport, CT                    via LinkedIn
# 740398        Ludwigshafen, Germany                        via XING
# 663221                    Singapore                    via Maukerja
# 649855                  England, UK                     via Jora UK
# 637982  Noida, Uttar Pradesh, India                   via AngelList
#
#        job_schedule_type  job_work_from_home          search_location  \
# 190161         Full-time               False                   France
# 304301         Full-time               False  Illinois, United States
# 234359         Full-time               False  Illinois, United States
# 521001        Internship               False  Illinois, United States
# 296061         Full-time               False           United Kingdom
# ...                  ...                 ...                      ...
# 780714         Full-time               False  New York, United States
# 740398        Internship               False                  Germany
# 663221              None               False                Singapore
# 649855         Full-time               False           United Kingdom
# 637982         Full-time               False                    India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 190161 2023-08-05 15:55:25                  False                 False
# 304301 2023-04-30 17:11:42                   True                 False
# 234359 2023-07-20 07:05:12                  False                 False
# 521001 2023-12-19 11:05:04                  False                 False
# 296061 2023-06-29 17:35:11                  False                 False
# ...                    ...                    ...                   ...
# 780714 2023-01-21 05:20:30                  False                 False
# 740398 2023-09-03 21:35:16                  False                 False
# 663221 2023-02-04 11:07:23                  False                 False
# 649855 2023-11-20 10:13:43                  False                 False
# 637982 2023-03-10 12:20:08                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 190161          France        None              NaN              NaN
# 304301   United States        None              NaN              NaN
# 234359   United States        None              NaN              NaN
# 521001   United States        None              NaN              NaN
# 296061  United Kingdom        None              NaN              NaN
# ...                ...         ...              ...              ...
# 780714   United States        None              NaN              NaN
# 740398         Germany        None              NaN              NaN
# 663221       Singapore        None              NaN              NaN
# 649855  United Kingdom        None              NaN              NaN
# 637982           India        None              NaN              NaN
#
#                      company_name  \
# 190161      Alter Solutions Group
# 304301                TekTree INC
# 234359          Abile Group, Inc.
# 521001         Shure Incorporated
# 296061               ClickJobs.io
# ...                           ...
# 780714              SynergisticIT
# 740398                    BASF SE
# 663221  Turnkey Group (pte.) Ltd.
# 649855                      Novai
# 637982                   Ripik.ai
#
#                                                job_skills  \
# 190161                        ['python', 'git', 'docker']
# 304301  ['sql', 'azure', 'databricks', 'ssis', 'ssrs',...
# 234359  ['python', 'c++', 'julia', 'go', 'r', 'aws', '...
# 521001                                               None
# 296061                 ['sql', 'python', 'azure', 'ssis']
# ...                                                   ...
# 780714  ['java', 'c++', 'javascript', 'python', 'sprin...
# 740398  ['python', 'r', 'pandas', 'tensorflow', 'dplyr...
# 663221                                           ['jira']
# 649855               ['python', 'aws', 'opencv', 'linux']
# 637982  ['python', 'sql', 'gcp', 'snowflake', 'power b...
#
#                                           job_type_skills
# 190161  {'other': ['git', 'docker'], 'programming': ['...
# 304301  {'analyst_tools': ['ssis', 'ssrs'], 'cloud': [...
# 234359  {'cloud': ['aws', 'gcp'], 'libraries': ['tenso...
# 521001                                               None
# 296061  {'analyst_tools': ['ssis'], 'cloud': ['azure']...
# ...                                                   ...
# 780714  {'analyst_tools': ['tableau'], 'libraries': ['...
# 740398  {'libraries': ['pandas', 'tensorflow', 'dplyr'...
# 663221                                {'async': ['jira']}
# 649855  {'cloud': ['aws'], 'libraries': ['opencv'], 'o...
# 637982  {'analyst_tools': ['power bi', 'tableau'], 'cl...
#
# [78574 rows x 17 columns]

# %%
# random_state= is Seed for the random number generator (useful for reproducibility).
df.sample(n=5, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}

# %%
# Use copy() method to create completely independent copy of the original DataFrame
df2 = df

# %%
df2['company_name'] = 'df2 changes affect original df'
df2['company_name']
# Out:
# 0         df2 changes affect original df
# 1         df2 changes affect original df
# 2         df2 changes affect original df
# 3         df2 changes affect original df
# 4         df2 changes affect original df
#                        ...
# 785736    df2 changes affect original df
# 785737    df2 changes affect original df
# 785738    df2 changes affect original df
# 785739    df2 changes affect original df
# 785740    df2 changes affect original df
# Name: company_name, Length: 785741, dtype: object

# %%
# Notice how df (original dataframe) was modified, even though we only changed df2
df['company_name']
# Out:
# 0         df2 changes affect original df
# 1         df2 changes affect original df
# 2         df2 changes affect original df
# 3         df2 changes affect original df
# 4         df2 changes affect original df
#                        ...
# 785736    df2 changes affect original df
# 785737    df2 changes affect original df
# 785738    df2 changes affect original df
# 785739    df2 changes affect original df
# 785740    df2 changes affect original df
# Name: company_name, Length: 785741, dtype: object

# %%
# Now, using copy()
df2 = df.copy()

# %%
df2['company_name'] = 'df2 created by independent copy of original dataframe'
df2['company_name']
# Out:
# 0         df2 created by independent copy of original da...
# 1         df2 created by independent copy of original da...
# 2         df2 created by independent copy of original da...
# 3         df2 created by independent copy of original da...
# 4         df2 created by independent copy of original da...
#                                 ...
# 785736    df2 created by independent copy of original da...
# 785737    df2 created by independent copy of original da...
# 785738    df2 created by independent copy of original da...
# 785739    df2 created by independent copy of original da...
# 785740    df2 created by independent copy of original da...
# Name: company_name, Length: 785741, dtype: object

# %%
# This time, df (original dataframe) remains unchanged.
df['company_name']
# Out:
# 0         df2 changes affect original df
# 1         df2 changes affect original df
# 2         df2 changes affect original df
# 3         df2 changes affect original df
# 4         df2 changes affect original df
#                        ...
# 785736    df2 changes affect original df
# 785737    df2 changes affect original df
# 785738    df2 changes affect original df
# 785739    df2 changes affect original df
# 785740    df2 changes affect original df
# Name: company_name, Length: 785741, dtype: object
